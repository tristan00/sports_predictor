# %%
import sys
sys.path.append('/home/td/Documents/sports_predictor/nba')
sys.path.append('/home/td/Documents/sports_predictor')

import pandas as pd
import lightgbm
import pandas
from sklearn import metrics, model_selection
from nba.common import (
    timeit,
)
import numpy as np
from nba.data_pipeline import load_general_feature_file
from scipy import stats
import copy

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
pd.set_option('display.max_colwidth', 1000)
# Out:
# Using TensorFlow backend.

# %%
cols_to_drop = []

# %%
class Model():

    def __init__(self, model_type, model_params, max_iter = 10000, early_stopping_rounds = 100):
        self.model_type = model_type
        self.model_params = model_params
        self.transformers_dict = dict()
        self.lightgbm_early_stopping_rounds = early_stopping_rounds
        self.lightgbm_max_iter = max_iter

    @timeit
    def fit(self, x, y):
        print('entered fit, x shape: {}'.format(x.shape))
        self.transformers_dict = dict()
        self.columns = x.columns

        if self.model_type == 'lightgbm':
            x_train, x_val, y_train, y_val = model_selection.train_test_split(x, y)
            lgtrain = lightgbm.Dataset(x_train, y_train)
            lgvalid = lightgbm.Dataset(x_val, y_val)

            self.model = lightgbm.train(
                self.model_params,
                lgtrain,
                num_boost_round=self.lightgbm_max_iter,
                valid_sets=[lgtrain, lgvalid],
                valid_names=['train', 'valid'],
                early_stopping_rounds=self.lightgbm_early_stopping_rounds,
                verbose_eval=100
            )

    @timeit
    def predict(self, x):
        if self.model_type == 'lightgbm':
            return self.model.predict(x, num_iteration=self.model.best_iteration)
            

    def evaluate(self):
        if self.model_type == 'lightgbm':
            output = []

            for i, j in zip(self.columns, self.model.feature_importance('gain', iteration=self.model.best_iteration)):
                output.append({'column': i, 'feature_importance': j})
            return pd.DataFrame.from_dict(output).sort_values('feature_importance', ascending=False)

# %%
def gbm_rfe(x, y, lgbm_params, step_size=.01, min_features=8, score_type = 'accuracy'):
    features = [i for i in x.columns.tolist() if i not in cols_to_drop]
    x_train, x_val, y_train, y_val = model_selection.train_test_split(x, y)
    feature_result_dict = dict()
   
    while len(features) > min_features:
        next_step_num_of_features = max(int(len(features)*(1-step_size)), min_features)
        model = Model('lightgbm', lgbm_params, early_stopping_rounds= 10)
        model.fit(x_train[features], y_train)
        
        preds_train = model.predict(x_train[features])
        preds_train = np.rint(preds_train).astype(int)
                
        preds_val = model.predict(x_val[features])
        preds_val = np.rint(preds_val).astype(int)
        
        if score_type == 'accuracy':
            feature_result_dict[tuple(features)] = metrics.accuracy_score(y_val, preds_val)
        if score_type == 'r2_score':
            feature_result_dict[tuple(features)] = metrics.r2_score(y_val, preds_val) 
        importances = model.evaluate().sort_values('feature_importance', ascending = False)
        print(len(features), metrics.accuracy_score(y_train, preds_train), metrics.accuracy_score(y_val, preds_val))
        importances = importances[importances['feature_importance'] > 0]

        features = importances['column'].tolist()[:next_step_num_of_features]
       
    features_selected = None
    max_score = 0
    for k, v in feature_result_dict.items():
        if v > max_score:
            features_selected = list(k)
            max_score = v
    return features_selected

# %%
def select_linear_features(x_train_glm, y_train, max_feature_corr):
    selected_cols_to_normal_target = set()
    feature_target_corr = []
    for i in x_train_glm.columns:
        # if 'accident_table' not in i and i not in cols_to_drop:
        if i not in cols_to_drop:
            slope, intercept, r_value, p_value, std_err = stats.linregress(x_train_glm[i], y_train)
            feature_target_corr.append((i, abs(r_value)))
    feature_target_corr = sorted(feature_target_corr, key = lambda x: x[1], reverse = True)
    selected_cols_to_normal_target.add(feature_target_corr[0][0])
    for i in feature_target_corr:
        too_correlated_to_features = False
        for j in selected_cols_to_normal_target:
            slope, intercept, r_value, p_value, std_err = stats.linregress(x_train_glm[i[0]], x_train_glm[j])
            if abs(r_value) > max_feature_corr:
                too_correlated_to_features = True
        if not too_correlated_to_features:
            selected_cols_to_normal_target.add(i[0])

    selected_cols_to_normal_target = list(selected_cols_to_normal_target)
    return selected_cols_to_normal_target

# %%
feature_df = load_general_feature_file()
x = feature_df.drop(['win', 'score_diff', 'key'], axis = 1)
y1 = feature_df['win']
y2 = feature_df['score_diff']
# Out:
# function: 'load_general_feature_file' starting
# function: 'load_general_feature_file' finished in  18.62 seconds

# %%
lgbm_params = {
    'boosting_type': 'gbdt',
    'objective': 'binary',
    'metric': 'binary_error',
    "learning_rate": 0.01,
    "max_depth": -1,
    'num_leaves': 127
}

lgbm_params_fast = copy.deepcopy(lgbm_params)
lgbm_params_fast['learning_rate'] = .1


model = Model('lightgbm', lgbm_params)
x_train, x_test, y_train, y_test = model_selection.train_test_split(x, y1)

# %%
classification_columns = gbm_rfe(x_train, y_train, lgbm_params_fast, step_size=.01, min_features=4, score_type = 'accuracy')
x_train.shape, len(classification_columns)
# Out:
# function: 'fit' starting
# entered fit, x shape: (5465, 14436)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [23]	train's binary_error: 0.00146413	valid's binary_error: 0.348208
# function: 'fit' finished in  66.34 seconds
# function: 'predict' starting
# function: 'predict' finished in  4.81 seconds
# function: 'predict' starting
# function: 'predict' finished in  4.48 seconds
# 14436 0.9118023787740165 0.637211855104281
# function: 'fit' starting
# entered fit, x shape: (5465, 2328)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [42]	train's binary_error: 0.000976086	valid's binary_error: 0.356255
# function: 'fit' finished in  18.43 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.37 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.35 seconds
# 2328 0.9101555352241537 0.6487376509330406
# function: 'fit' starting
# entered fit, x shape: (5465, 1932)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [13]	train's binary_error: 0.00634456	valid's binary_error: 0.354792
# function: 'fit' finished in  6.69 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.36 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.29 seconds
# 1932 0.9064958828911254 0.6427003293084522
# function: 'fit' starting
# entered fit, x shape: (5465, 994)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [8]	train's binary_error: 0.0292826	valid's binary_error: 0.351134
# function: 'fit' finished in  2.81 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.15 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.13 seconds
# 994 0.8902104300091491 0.6240395170142701
# function: 'fit' starting
# entered fit, x shape: (5465, 592)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [25]	train's binary_error: 0.00122011	valid's binary_error: 0.326262
# function: 'fit' finished in  3.39 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.09 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.08 seconds
# 592 0.9174748398902104 0.6361141602634468
# function: 'fit' starting
# entered fit, x shape: (5465, 584)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [10]	train's binary_error: 0.0202538	valid's binary_error: 0.353328
# function: 'fit' finished in  1.85 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.08 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.07 seconds
# 584 0.8964318389752973 0.6427003293084522
# function: 'fit' starting
# entered fit, x shape: (5465, 494)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [41]	train's binary_error: 0.00146413	valid's binary_error: 0.328456
# function: 'fit' finished in  3.95 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.08 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.06 seconds
# 494 0.9167429094236048 0.6388583973655324
# function: 'fit' starting
# entered fit, x shape: (5465, 489)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [11]	train's binary_error: 0.0156174	valid's binary_error: 0.347476
# function: 'fit' finished in  1.43 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.07 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.06 seconds
# 489 0.9013723696248856 0.6514818880351262
# function: 'fit' starting
# entered fit, x shape: (5465, 443)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [16]	train's binary_error: 0.00414837	valid's binary_error: 0.339429
# function: 'fit' finished in  1.95 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.06 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.05 seconds
# 443 0.9119853613906679 0.641602634467618
# function: 'fit' starting
# entered fit, x shape: (5465, 434)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [24]	train's binary_error: 0.00146413	valid's binary_error: 0.338698
# function: 'fit' finished in  1.81 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.09 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.07 seconds
# 434 0.914181152790485 0.6405049396267838
# function: 'fit' starting
# entered fit, x shape: (5465, 429)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [10]	train's binary_error: 0.02245	valid's binary_error: 0.327725
# function: 'fit' finished in  1.62 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.08 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.07 seconds
# 429 0.9011893870082343 0.6394072447859495
# function: 'fit' starting
# entered fit, x shape: (5465, 395)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [12]	train's binary_error: 0.0143973	valid's binary_error: 0.332114
# function: 'fit' finished in  1.20 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.07 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.06 seconds
# 395 0.9061299176578225 0.6218441273326015
# function: 'fit' starting
# entered fit, x shape: (5465, 370)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [26]	train's binary_error: 0.00146413	valid's binary_error: 0.329188
# function: 'fit' finished in  2.90 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.06 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.05 seconds
# 370 0.9165599268069533 0.6421514818880352
# function: 'fit' starting
# entered fit, x shape: (5465, 366)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [9]	train's binary_error: 0.0331869	valid's binary_error: 0.348939
# function: 'fit' finished in  1.11 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.05 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.04 seconds
# 366 0.8878316559926807 0.6427003293084522
# function: 'fit' starting
# entered fit, x shape: (5465, 348)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [37]	train's binary_error: 0.000976086	valid's binary_error: 0.32992
# function: 'fit' finished in  1.97 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.07 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.05 seconds
# 348 0.9167429094236048 0.6498353457738749
# function: 'fit' starting
# entered fit, x shape: (5465, 344)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [33]	train's binary_error: 0.00146413	valid's binary_error: 0.349671
# function: 'fit' finished in  2.26 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.05 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.04 seconds
# 344 0.9114364135407136 0.6437980241492866
# function: 'fit' starting
# entered fit, x shape: (5465, 340)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [20]	train's binary_error: 0.00268424	valid's binary_error: 0.32553
# function: 'fit' finished in  1.96 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.08 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.07 seconds
# 340 0.9165599268069533 0.6492864983534578
# function: 'fit' starting
# entered fit, x shape: (5465, 336)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [16]	train's binary_error: 0.00854075	valid's binary_error: 0.35406
# function: 'fit' finished in  1.24 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.06 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.04 seconds
# 336 0.905032021957914 0.6383095499451152
# function: 'fit' starting
# entered fit, x shape: (5465, 332)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [5]	train's binary_error: 0.0700342	valid's binary_error: 0.355523
# function: 'fit' finished in  0.99 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.05 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.04 seconds
# 332 0.8585544373284538 0.6383095499451152
# function: 'fit' starting
# entered fit, x shape: (5465, 272)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [14]	train's binary_error: 0.0156174	valid's binary_error: 0.349671
# function: 'fit' finished in  1.31 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.05 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.04 seconds
# 272 0.9008234217749314 0.6394072447859495
# function: 'fit' starting
# entered fit, x shape: (5465, 269)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [16]	train's binary_error: 0.00780869	valid's binary_error: 0.334309
# function: 'fit' finished in  0.91 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.04 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.03 seconds
# 269 0.9105215004574565 0.6476399560922064
# function: 'fit' starting
# entered fit, x shape: (5465, 266)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [5]	train's binary_error: 0.0746706	valid's binary_error: 0.335772
# function: 'fit' finished in  1.17 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.05 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.04 seconds
# 266 0.8600182982616651 0.641602634467618
# function: 'fit' starting
# entered fit, x shape: (5465, 237)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [23]	train's binary_error: 0.00146413	valid's binary_error: 0.334309
# function: 'fit' finished in  1.52 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.04 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.03 seconds
# 237 0.9152790484903934 0.6350164654226125
# function: 'fit' starting
# entered fit, x shape: (5465, 234)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [19]	train's binary_error: 0.00561249	valid's binary_error: 0.334309
# function: 'fit' finished in  0.84 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.04 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.03 seconds
# 234 0.9121683440073193 0.6624588364434687
# function: 'fit' starting
# entered fit, x shape: (5465, 231)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [10]	train's binary_error: 0.0329429	valid's binary_error: 0.340161
# function: 'fit' finished in  0.97 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.04 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.03 seconds
# 231 0.8902104300091491 0.6317233809001098
# function: 'fit' starting
# entered fit, x shape: (5465, 228)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [7]	train's binary_error: 0.0553929	valid's binary_error: 0.327725
# function: 'fit' finished in  1.08 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.04 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.03 seconds
# 228 0.8764867337602927 0.6361141602634468
# function: 'fit' starting
# entered fit, x shape: (5465, 221)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [20]	train's binary_error: 0.00414837	valid's binary_error: 0.335772
# function: 'fit' finished in  0.75 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.04 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.03 seconds
# 221 0.912900274473925 0.6470911086717892
# function: 'fit' starting
# entered fit, x shape: (5465, 218)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [17]	train's binary_error: 0.00732064	valid's binary_error: 0.332114
# function: 'fit' finished in  1.09 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.04 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.04 seconds
# 218 0.9114364135407136 0.6487376509330406
# function: 'fit' starting
# entered fit, x shape: (5465, 215)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [5]	train's binary_error: 0.0817472	valid's binary_error: 0.34455
# function: 'fit' finished in  0.74 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.03 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.03 seconds
# 215 0.852516010978957 0.6421514818880352
# function: 'fit' starting
# entered fit, x shape: (5465, 193)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [14]	train's binary_error: 0.022938	valid's binary_error: 0.349671
# function: 'fit' finished in  0.90 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.03 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# 193 0.8953339432753888 0.6350164654226125
# function: 'fit' starting
# entered fit, x shape: (5465, 191)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [17]	train's binary_error: 0.011225	valid's binary_error: 0.318947
# function: 'fit' finished in  0.62 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.03 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.03 seconds
# 191 0.9118023787740165 0.6311745334796927
# function: 'fit' starting
# entered fit, x shape: (5465, 189)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [7]	train's binary_error: 0.0605173	valid's binary_error: 0.351865
# function: 'fit' finished in  0.71 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.03 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.03 seconds
# 189 0.8666056724611162 0.6289791437980241
# function: 'fit' starting
# entered fit, x shape: (5465, 187)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [14]	train's binary_error: 0.0200098	valid's binary_error: 0.328456
# function: 'fit' finished in  1.22 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.03 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# 187 0.902836230558097 0.632821075740944
# function: 'fit' starting
# entered fit, x shape: (5465, 185)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [15]	train's binary_error: 0.0139092	valid's binary_error: 0.332114
# function: 'fit' finished in  1.25 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.03 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# 185 0.9064958828911254 0.6465422612513722
# function: 'fit' starting
# entered fit, x shape: (5465, 183)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [22]	train's binary_error: 0.00317228	valid's binary_error: 0.322604
# function: 'fit' finished in  0.56 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.03 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# 183 0.9169258920402562 0.6278814489571899
# function: 'fit' starting
# entered fit, x shape: (5465, 181)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [18]	train's binary_error: 0.0102489	valid's binary_error: 0.323336
# function: 'fit' finished in  0.49 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.03 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# 181 0.9114364135407136 0.641602634467618
# function: 'fit' starting
# entered fit, x shape: (5465, 179)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [35]	train's binary_error: 0.00146413	valid's binary_error: 0.337966
# function: 'fit' finished in  0.84 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.04 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.05 seconds
# 179 0.9143641354071363 0.6443468715697036
# function: 'fit' starting
# entered fit, x shape: (5465, 177)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [11]	train's binary_error: 0.0317228	valid's binary_error: 0.322604
# function: 'fit' finished in  0.39 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.03 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.03 seconds
# 177 0.8955169258920402 0.6350164654226125
# function: 'fit' starting
# entered fit, x shape: (5465, 175)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [32]	train's binary_error: 0.00146413	valid's binary_error: 0.333577
# function: 'fit' finished in  1.45 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.04 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# 175 0.9154620311070448 0.6383095499451152
# function: 'fit' starting
# entered fit, x shape: (5465, 173)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [12]	train's binary_error: 0.0295266	valid's binary_error: 0.332846
# function: 'fit' finished in  0.94 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.03 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.03 seconds
# 173 0.8946020128087832 0.6350164654226125
# function: 'fit' starting
# entered fit, x shape: (5465, 171)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [13]	train's binary_error: 0.0236701	valid's binary_error: 0.321141
# function: 'fit' finished in  0.64 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.03 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# 171 0.90192131747484 0.6410537870472008
# function: 'fit' starting
# entered fit, x shape: (5465, 169)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [20]	train's binary_error: 0.00488043	valid's binary_error: 0.332114
# function: 'fit' finished in  0.71 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.03 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# 169 0.9132662397072279 0.637211855104281
# function: 'fit' starting
# entered fit, x shape: (5465, 167)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [36]	train's binary_error: 0.00146413	valid's binary_error: 0.321873
# function: 'fit' finished in  1.76 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.03 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# 167 0.9183897529734675 0.6421514818880352
# function: 'fit' starting
# entered fit, x shape: (5465, 165)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [34]	train's binary_error: 0.00146413	valid's binary_error: 0.321873
# function: 'fit' finished in  1.01 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.03 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# 165 0.9183897529734675 0.6465422612513722
# function: 'fit' starting
# entered fit, x shape: (5465, 163)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [22]	train's binary_error: 0.0034163	valid's binary_error: 0.337235
# function: 'fit' finished in  0.72 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.03 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# 163 0.9130832570905764 0.6361141602634468
# function: 'fit' starting
# entered fit, x shape: (5465, 161)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [13]	train's binary_error: 0.0278184	valid's binary_error: 0.333577
# function: 'fit' finished in  1.06 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.03 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# 161 0.8956999085086916 0.6454445664105378
# function: 'fit' starting
# entered fit, x shape: (5465, 159)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [14]	train's binary_error: 0.0239141	valid's binary_error: 0.32553
# function: 'fit' finished in  0.93 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.03 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.03 seconds
# 159 0.90064043915828 0.6432491767288694
# function: 'fit' starting
# entered fit, x shape: (5465, 157)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [17]	train's binary_error: 0.0119571	valid's binary_error: 0.329188
# function: 'fit' finished in  0.48 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.03 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.03 seconds
# 157 0.9086916742909423 0.6399560922063666
# function: 'fit' starting
# entered fit, x shape: (5465, 155)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [21]	train's binary_error: 0.00488043	valid's binary_error: 0.318215
# function: 'fit' finished in  1.33 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.04 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.04 seconds
# 155 0.9167429094236048 0.6394072447859495
# function: 'fit' starting
# entered fit, x shape: (5465, 153)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [15]	train's binary_error: 0.0156174	valid's binary_error: 0.333577
# function: 'fit' finished in  1.10 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.05 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# 153 0.9048490393412626 0.6476399560922064
# function: 'fit' starting
# entered fit, x shape: (5465, 151)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [5]	train's binary_error: 0.0817472	valid's binary_error: 0.314557
# function: 'fit' finished in  0.40 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# 151 0.8600182982616651 0.6383095499451152
# function: 'fit' starting
# entered fit, x shape: (5465, 147)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [8]	train's binary_error: 0.0617374	valid's binary_error: 0.350402
# function: 'fit' finished in  0.30 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# 147 0.8660567246111619 0.632821075740944
# function: 'fit' starting
# entered fit, x shape: (5465, 145)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [12]	train's binary_error: 0.0317228	valid's binary_error: 0.330651
# function: 'fit' finished in  0.83 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.03 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# 145 0.8935041171088747 0.6273326015367727
# function: 'fit' starting
# entered fit, x shape: (5465, 143)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [12]	train's binary_error: 0.0324549	valid's binary_error: 0.333577
# function: 'fit' finished in  0.90 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.04 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.04 seconds
# 143 0.8922232387923147 0.637211855104281
# function: 'fit' starting
# entered fit, x shape: (5465, 141)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [31]	train's binary_error: 0.00170815	valid's binary_error: 0.321141
# function: 'fit' finished in  1.69 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.03 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# 141 0.9183897529734675 0.6448957189901208
# function: 'fit' starting
# entered fit, x shape: (5465, 139)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [29]	train's binary_error: 0.00170815	valid's binary_error: 0.326993
# function: 'fit' finished in  0.57 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# 139 0.9169258920402562 0.641602634467618
# function: 'fit' starting
# entered fit, x shape: (5465, 137)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [7]	train's binary_error: 0.0705222	valid's binary_error: 0.337966
# function: 'fit' finished in  0.43 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# 137 0.862580054894785 0.6350164654226125
# function: 'fit' starting
# entered fit, x shape: (5465, 135)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [8]	train's binary_error: 0.0622255	valid's binary_error: 0.341624
# function: 'fit' finished in  0.38 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# 135 0.8678865507776761 0.6240395170142701
# function: 'fit' starting
# entered fit, x shape: (5465, 133)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [28]	train's binary_error: 0.00244021	valid's binary_error: 0.334309
# function: 'fit' finished in  0.72 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# 133 0.9145471180237877 0.6394072447859495
# function: 'fit' starting
# entered fit, x shape: (5465, 131)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [17]	train's binary_error: 0.0124451	valid's binary_error: 0.298464
# function: 'fit' finished in  0.84 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.03 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# 131 0.9160109789569991 0.641602634467618
# function: 'fit' starting
# entered fit, x shape: (5465, 129)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [13]	train's binary_error: 0.0297706	valid's binary_error: 0.324799
# function: 'fit' finished in  0.70 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# 129 0.8964318389752973 0.6437980241492866
# function: 'fit' starting
# entered fit, x shape: (5465, 127)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [18]	train's binary_error: 0.0129331	valid's binary_error: 0.32041
# function: 'fit' finished in  0.69 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.03 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# 127 0.9101555352241537 0.6361141602634468
# function: 'fit' starting
# entered fit, x shape: (5465, 125)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [12]	train's binary_error: 0.0387994	valid's binary_error: 0.345282
# function: 'fit' finished in  0.38 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# 125 0.8845379688929552 0.6311745334796927
# function: 'fit' starting
# entered fit, x shape: (5465, 123)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [7]	train's binary_error: 0.0778429	valid's binary_error: 0.32992
# function: 'fit' finished in  0.46 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# 123 0.859103385178408 0.6355653128430296
# function: 'fit' starting
# entered fit, x shape: (5465, 121)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [26]	train's binary_error: 0.00292826	valid's binary_error: 0.310168
# function: 'fit' finished in  1.19 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.04 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.03 seconds
# 121 0.9202195791399816 0.6399560922063666
# function: 'fit' starting
# entered fit, x shape: (5465, 119)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [15]	train's binary_error: 0.022938	valid's binary_error: 0.338698
# function: 'fit' finished in  0.84 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# 119 0.8980786825251601 0.6448957189901208
# function: 'fit' starting
# entered fit, x shape: (5465, 117)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [19]	train's binary_error: 0.0107369	valid's binary_error: 0.330651
# function: 'fit' finished in  0.41 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# 117 0.9092406221408966 0.6454445664105378
# function: 'fit' starting
# entered fit, x shape: (5465, 115)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [36]	train's binary_error: 0.00122011	valid's binary_error: 0.321141
# function: 'fit' finished in  0.58 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# 115 0.9187557182067704 0.6553238199780461
# function: 'fit' starting
# entered fit, x shape: (5465, 113)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [11]	train's binary_error: 0.045144	valid's binary_error: 0.338698
# function: 'fit' finished in  0.67 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# 113 0.8814272644098811 0.6366630076838639
# function: 'fit' starting
# entered fit, x shape: (5465, 111)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [19]	train's binary_error: 0.011469	valid's binary_error: 0.324067
# function: 'fit' finished in  1.01 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.03 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# 111 0.9103385178408051 0.6437980241492866
# function: 'fit' starting
# entered fit, x shape: (5465, 109)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [13]	train's binary_error: 0.0314788	valid's binary_error: 0.326993
# function: 'fit' finished in  0.69 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.03 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# 109 0.8946020128087832 0.637211855104281
# function: 'fit' starting
# entered fit, x shape: (5465, 107)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [17]	train's binary_error: 0.0143973	valid's binary_error: 0.321873
# function: 'fit' finished in  0.33 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# 107 0.9086916742909423 0.6410537870472008
# function: 'fit' starting
# entered fit, x shape: (5465, 105)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [12]	train's binary_error: 0.0431918	valid's binary_error: 0.312363
# function: 'fit' finished in  0.52 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# 105 0.8894784995425434 0.6427003293084522
# function: 'fit' starting
# entered fit, x shape: (5465, 103)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [12]	train's binary_error: 0.0380673	valid's binary_error: 0.316752
# function: 'fit' finished in  0.69 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# 103 0.8922232387923147 0.6256860592755215
# function: 'fit' starting
# entered fit, x shape: (5465, 101)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [21]	train's binary_error: 0.00878477	valid's binary_error: 0.32992
# function: 'fit' finished in  1.15 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# 101 0.9108874656907594 0.6520307354555434
# function: 'fit' starting
# entered fit, x shape: (5465, 99)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [11]	train's binary_error: 0.0466081	valid's binary_error: 0.324067
# function: 'fit' finished in  0.33 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# 99 0.8839890210430009 0.6317233809001098
# function: 'fit' starting
# entered fit, x shape: (5465, 98)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [16]	train's binary_error: 0.0197657	valid's binary_error: 0.331383
# function: 'fit' finished in  0.40 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# 98 0.9022872827081427 0.6427003293084522
# function: 'fit' starting
# entered fit, x shape: (5465, 97)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [20]	train's binary_error: 0.0104929	valid's binary_error: 0.326993
# function: 'fit' finished in  0.31 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# 97 0.9103385178408051 0.6405049396267838
# function: 'fit' starting
# entered fit, x shape: (5465, 96)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [14]	train's binary_error: 0.0302587	valid's binary_error: 0.347476
# function: 'fit' finished in  1.12 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# 96 0.8903934126258005 0.641602634467618
# function: 'fit' starting
# entered fit, x shape: (5465, 95)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [41]	train's binary_error: 0.000976086	valid's binary_error: 0.314557
# function: 'fit' finished in  1.34 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# 95 0.9205855443732845 0.6399560922063666
# function: 'fit' starting
# entered fit, x shape: (5465, 94)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [29]	train's binary_error: 0.00268424	valid's binary_error: 0.337235
# function: 'fit' finished in  0.43 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# 94 0.9136322049405307 0.641602634467618
# function: 'fit' starting
# entered fit, x shape: (5465, 93)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [12]	train's binary_error: 0.045388	valid's binary_error: 0.334309
# function: 'fit' finished in  0.25 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# 93 0.8823421774931381 0.6421514818880352
# function: 'fit' starting
# entered fit, x shape: (5465, 92)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [26]	train's binary_error: 0.0034163	valid's binary_error: 0.32992
# function: 'fit' finished in  1.01 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# 92 0.9149130832570905 0.6311745334796927
# function: 'fit' starting
# entered fit, x shape: (5465, 91)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [25]	train's binary_error: 0.00561249	valid's binary_error: 0.316752
# function: 'fit' finished in  1.00 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.03 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# 91 0.9165599268069533 0.6394072447859495
# function: 'fit' starting
# entered fit, x shape: (5465, 90)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [8]	train's binary_error: 0.0710102	valid's binary_error: 0.341624
# function: 'fit' finished in  0.50 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# 90 0.8612991765782251 0.6300768386388584
# function: 'fit' starting
# entered fit, x shape: (5465, 89)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [23]	train's binary_error: 0.00463641	valid's binary_error: 0.30139
# function: 'fit' finished in  0.44 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# 89 0.9211344922232388 0.6405049396267838
# function: 'fit' starting
# entered fit, x shape: (5465, 88)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [12]	train's binary_error: 0.0431918	valid's binary_error: 0.32553
# function: 'fit' finished in  0.46 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.03 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.03 seconds
# 88 0.8861848124428179 0.6256860592755215
# function: 'fit' starting
# entered fit, x shape: (5465, 87)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [21]	train's binary_error: 0.0104929	valid's binary_error: 0.32992
# function: 'fit' finished in  1.02 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# 87 0.9096065873741994 0.6295279912184413
# function: 'fit' starting
# entered fit, x shape: (5465, 86)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [22]	train's binary_error: 0.0068326	valid's binary_error: 0.331383
# function: 'fit' finished in  0.93 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# 86 0.9119853613906679 0.6339187705817783
# function: 'fit' starting
# entered fit, x shape: (5465, 85)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [5]	train's binary_error: 0.103465	valid's binary_error: 0.337966
# function: 'fit' finished in  0.28 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# 85 0.8378774016468435 0.6339187705817783
# function: 'fit' starting
# entered fit, x shape: (5465, 84)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [18]	train's binary_error: 0.0175695	valid's binary_error: 0.342356
# function: 'fit' finished in  0.27 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# 84 0.9011893870082343 0.6558726673984633
# function: 'fit' starting
# entered fit, x shape: (5465, 83)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [30]	train's binary_error: 0.00219619	valid's binary_error: 0.32041
# function: 'fit' finished in  0.85 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# 83 0.9182067703568161 0.6421514818880352
# function: 'fit' starting
# entered fit, x shape: (5465, 82)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [33]	train's binary_error: 0.00244021	valid's binary_error: 0.312363
# function: 'fit' finished in  1.44 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# 82 0.9200365965233303 0.6427003293084522
# function: 'fit' starting
# entered fit, x shape: (5465, 81)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [20]	train's binary_error: 0.0129331	valid's binary_error: 0.331383
# function: 'fit' finished in  0.50 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# 81 0.9074107959743825 0.6448957189901208
# function: 'fit' starting
# entered fit, x shape: (5465, 80)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [7]	train's binary_error: 0.0841874	valid's binary_error: 0.32553
# function: 'fit' finished in  0.27 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# 80 0.8554437328453797 0.6322722283205269
# function: 'fit' starting
# entered fit, x shape: (5465, 79)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [36]	train's binary_error: 0.00122011	valid's binary_error: 0.304316
# function: 'fit' finished in  1.59 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# 79 0.922964318389753 0.6558726673984633
# function: 'fit' starting
# entered fit, x shape: (5465, 78)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [28]	train's binary_error: 0.00170815	valid's binary_error: 0.321873
# function: 'fit' finished in  1.02 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# 78 0.9182067703568161 0.654774972557629
# function: 'fit' starting
# entered fit, x shape: (5465, 77)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [37]	train's binary_error: 0.00219619	valid's binary_error: 0.323336
# function: 'fit' finished in  0.93 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# 77 0.9174748398902104 0.6498353457738749
# function: 'fit' starting
# entered fit, x shape: (5465, 76)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [20]	train's binary_error: 0.0151293	valid's binary_error: 0.3109
# function: 'fit' finished in  0.38 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# 76 0.9108874656907594 0.6476399560922064
# function: 'fit' starting
# entered fit, x shape: (5465, 75)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [8]	train's binary_error: 0.0788189	valid's binary_error: 0.315289
# function: 'fit' finished in  0.18 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# 75 0.8620311070448308 0.6432491767288694
# function: 'fit' starting
# entered fit, x shape: (5465, 74)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [12]	train's binary_error: 0.0478282	valid's binary_error: 0.324799
# function: 'fit' finished in  0.34 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# 74 0.8828911253430924 0.6410537870472008
# function: 'fit' starting
# entered fit, x shape: (5465, 73)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [16]	train's binary_error: 0.0290386	valid's binary_error: 0.336503
# function: 'fit' finished in  0.24 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# 73 0.8940530649588289 0.6470911086717892
# function: 'fit' starting
# entered fit, x shape: (5465, 72)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [30]	train's binary_error: 0.00268424	valid's binary_error: 0.313826
# function: 'fit' finished in  0.41 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# 72 0.9194876486733761 0.6322722283205269
# function: 'fit' starting
# entered fit, x shape: (5465, 71)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [22]	train's binary_error: 0.0124451	valid's binary_error: 0.324799
# function: 'fit' finished in  0.41 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# 71 0.909423604757548 0.6350164654226125
# function: 'fit' starting
# entered fit, x shape: (5465, 70)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [14]	train's binary_error: 0.0395315	valid's binary_error: 0.313826
# function: 'fit' finished in  0.84 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# 70 0.8918572735590119 0.6542261251372119
# function: 'fit' starting
# entered fit, x shape: (5465, 69)
# ...
# function: 'predict' finished in  0.01 seconds
# 40 0.9004574565416286 0.6361141602634468
# function: 'fit' starting
# entered fit, x shape: (5465, 39)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [23]	train's binary_error: 0.0200098	valid's binary_error: 0.319678
# function: 'fit' finished in  0.74 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# 39 0.905032021957914 0.6476399560922064
# function: 'fit' starting
# entered fit, x shape: (5465, 38)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [18]	train's binary_error: 0.0407516	valid's binary_error: 0.322604
# function: 'fit' finished in  0.23 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# 38 0.8887465690759377 0.6410537870472008
# function: 'fit' starting
# entered fit, x shape: (5465, 37)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [7]	train's binary_error: 0.111762	valid's binary_error: 0.321141
# function: 'fit' finished in  0.09 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# 37 0.835864592863678 0.6394072447859495
# function: 'fit' starting
# entered fit, x shape: (5465, 36)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [22]	train's binary_error: 0.0258663	valid's binary_error: 0.332846
# function: 'fit' finished in  0.21 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# 36 0.8973467520585544 0.6355653128430296
# function: 'fit' starting
# entered fit, x shape: (5465, 35)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [21]	train's binary_error: 0.0324549	valid's binary_error: 0.332846
# function: 'fit' finished in  0.79 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# 35 0.8924062214089662 0.6443468715697036
# function: 'fit' starting
# entered fit, x shape: (5465, 34)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [13]	train's binary_error: 0.0756467	valid's binary_error: 0.318947
# function: 'fit' finished in  0.47 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# 34 0.863494967978042 0.632821075740944
# function: 'fit' starting
# entered fit, x shape: (5465, 33)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [16]	train's binary_error: 0.0510005	valid's binary_error: 0.307974
# function: 'fit' finished in  0.57 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# 33 0.8847209515096066 0.6443468715697036
# function: 'fit' starting
# entered fit, x shape: (5465, 32)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [25]	train's binary_error: 0.0183016	valid's binary_error: 0.302121
# function: 'fit' finished in  0.52 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# 32 0.910704483074108 0.6427003293084522
# function: 'fit' starting
# entered fit, x shape: (5465, 31)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [6]	train's binary_error: 0.129819	valid's binary_error: 0.337966
# function: 'fit' finished in  0.08 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# 31 0.8181152790484904 0.6300768386388584
# function: 'fit' starting
# entered fit, x shape: (5465, 30)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [34]	train's binary_error: 0.00610054	valid's binary_error: 0.338698
# function: 'fit' finished in  0.27 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# 30 0.910704483074108 0.6454445664105378
# function: 'fit' starting
# entered fit, x shape: (5465, 29)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [36]	train's binary_error: 0.00512445	valid's binary_error: 0.316752
# function: 'fit' finished in  0.25 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# 29 0.9169258920402562 0.6350164654226125
# function: 'fit' starting
# entered fit, x shape: (5465, 28)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [29]	train's binary_error: 0.011469	valid's binary_error: 0.328456
# function: 'fit' finished in  0.85 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# 28 0.9092406221408966 0.6355653128430296
# function: 'fit' starting
# entered fit, x shape: (5465, 27)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [15]	train's binary_error: 0.0675939	valid's binary_error: 0.318215
# function: 'fit' finished in  0.45 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# 27 0.8697163769441904 0.6350164654226125
# function: 'fit' starting
# entered fit, x shape: (5465, 26)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [19]	train's binary_error: 0.0449	valid's binary_error: 0.343087
# function: 'fit' finished in  0.57 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# 26 0.880512351326624 0.645993413830955
# function: 'fit' starting
# entered fit, x shape: (5465, 25)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [9]	train's binary_error: 0.10981	valid's binary_error: 0.32041
# function: 'fit' finished in  0.30 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.00 seconds
# 25 0.8375114364135408 0.6256860592755215
# function: 'fit' starting
# entered fit, x shape: (5465, 24)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [19]	train's binary_error: 0.056369	valid's binary_error: 0.315289
# function: 'fit' finished in  0.14 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# 24 0.8788655077767612 0.6437980241492866
# function: 'fit' starting
# entered fit, x shape: (5465, 23)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [24]	train's binary_error: 0.0297706	valid's binary_error: 0.339429
# function: 'fit' finished in  0.13 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.00 seconds
# 23 0.892772186642269 0.641602634467618
# function: 'fit' starting
# entered fit, x shape: (5465, 22)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [24]	train's binary_error: 0.0307467	valid's binary_error: 0.333577
# function: 'fit' finished in  0.26 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# 22 0.8935041171088747 0.6350164654226125
# function: 'fit' starting
# entered fit, x shape: (5465, 21)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [30]	train's binary_error: 0.0187897	valid's binary_error: 0.326993
# function: 'fit' finished in  0.15 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.00 seconds
# 21 0.9041171088746569 0.6317233809001098
# function: 'fit' starting
# entered fit, x shape: (5465, 20)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [12]	train's binary_error: 0.0995608	valid's binary_error: 0.324067
# function: 'fit' finished in  0.10 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.00 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# 20 0.8442817932296431 0.6262349066959385
# function: 'fit' starting
# entered fit, x shape: (5465, 19)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [10]	train's binary_error: 0.122255	valid's binary_error: 0.334309
# function: 'fit' finished in  0.11 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.00 seconds
# 19 0.8247026532479415 0.6465422612513722
# function: 'fit' starting
# entered fit, x shape: (5465, 18)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [10]	train's binary_error: 0.114934	valid's binary_error: 0.328456
# function: 'fit' finished in  0.13 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.00 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# 18 0.8316559926806953 0.6284302963776071
# function: 'fit' starting
# entered fit, x shape: (5465, 17)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [15]	train's binary_error: 0.0929722	valid's binary_error: 0.32992
# function: 'fit' finished in  0.47 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.00 seconds
# 17 0.8477584629460201 0.6448957189901208
# function: 'fit' starting
# entered fit, x shape: (5465, 16)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [15]	train's binary_error: 0.0939483	valid's binary_error: 0.321141
# function: 'fit' finished in  0.43 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# 16 0.8492223238792315 0.6405049396267838
# function: 'fit' starting
# entered fit, x shape: (5465, 15)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [11]	train's binary_error: 0.122011	valid's binary_error: 0.34455
# function: 'fit' finished in  0.41 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.00 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.00 seconds
# 15 0.822323879231473 0.6361141602634468
# function: 'fit' starting
# entered fit, x shape: (5465, 14)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [8]	train's binary_error: 0.152025	valid's binary_error: 0.336503
# function: 'fit' finished in  0.46 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.00 seconds
# 14 0.8018298261665142 0.6339187705817783
# function: 'fit' starting
# entered fit, x shape: (5465, 13)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [15]	train's binary_error: 0.110786	valid's binary_error: 0.347476
# function: 'fit' finished in  0.44 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# 13 0.8300091491308326 0.6443468715697036
# function: 'fit' starting
# entered fit, x shape: (5465, 12)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [5]	train's binary_error: 0.181308	valid's binary_error: 0.341624
# function: 'fit' finished in  0.06 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.00 seconds
# 12 0.7785910338517841 0.6437980241492866
# function: 'fit' starting
# entered fit, x shape: (5465, 11)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [31]	train's binary_error: 0.0395315	valid's binary_error: 0.337235
# function: 'fit' finished in  0.13 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.00 seconds
# 11 0.8860018298261665 0.6399560922063666
# function: 'fit' starting
# entered fit, x shape: (5465, 10)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [5]	train's binary_error: 0.197413	valid's binary_error: 0.383321
# function: 'fit' finished in  0.11 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.00 seconds
# 10 0.7560841720036596 0.5998902305159166
# function: 'fit' starting
# entered fit, x shape: (5465, 9)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [19]	train's binary_error: 0.0971205	valid's binary_error: 0.3782
# function: 'fit' finished in  0.08 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.00 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.00 seconds
# 9 0.8325709057639524 0.6163556531284303
# function: 'fit' starting
# entered fit, x shape: (5465, 8)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [14]	train's binary_error: 0.132504	valid's binary_error: 0.380395
# function: 'fit' finished in  0.06 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.00 seconds
# 8 0.8054894784995426 0.6190998902305159
# function: 'fit' starting
# entered fit, x shape: (5465, 7)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [26]	train's binary_error: 0.0771108	valid's binary_error: 0.38259
# function: 'fit' finished in  0.13 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.00 seconds
# 7 0.8464775846294602 0.6218441273326015
# function: 'fit' starting
# entered fit, x shape: (5465, 6)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [6]	train's binary_error: 0.227428	valid's binary_error: 0.38259
# function: 'fit' finished in  0.06 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.00 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.01 seconds
# 6 0.7337602927721867 0.6136114160263447
# function: 'fit' starting
# entered fit, x shape: (5465, 5)
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [8]	train's binary_error: 0.207418	valid's binary_error: 0.381127
# function: 'fit' finished in  0.05 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.02 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.00 seconds
# 5 0.7491308325709057 0.6081229418221734
# ((7287, 14436), 234)

# %%
model.fit(x_train[classification_columns], y_train)
preds = model.predict(x_test[classification_columns])
preds = np.rint(preds).astype(int)     
metrics.accuracy_score(y_test, preds)
# Out:
# function: 'fit' starting
# entered fit, x shape: (7287, 234)
# Training until validation scores don't improve for 100 rounds
# [100]	train's binary_error: 0.0570906	valid's binary_error: 0.362239
# [200]	train's binary_error: 0.010796	valid's binary_error: 0.351262
# [300]	train's binary_error: 0.00182983	valid's binary_error: 0.349616
# Early stopping, best iteration is:
# [235]	train's binary_error: 0.0073193	valid's binary_error: 0.34303
# function: 'fit' finished in  12.88 seconds
# function: 'predict' starting
# function: 'predict' finished in  0.05 seconds
# 0.6270069987649238

# %%
model.evaluate().head(100)
# Out:
#                                                                                                                column  feature_importance
# 0                                                                      team_pregame_rating_0_diff_vs_opponent_feature        26234.969584
# 1                                                                                       home_diff_vs_opponent_feature        10834.238347
# 2                                                       team_aggregate_past_50_game_skew_win_diff_vs_opponent_feature         3621.864334
# 8             team_aggregate_past_50_game_avg_player_stats_aggregated_by_game_plus_minus_max_diff_vs_opponent_feature         2847.901426
# 3          team_aggregate_past_20_game_avg_player_stats_aggregated_by_game_plus_minus_median_diff_vs_opponent_feature         2232.200192
# 39                team_aggregate_past_5_game_avg_player_stats_aggregated_by_game_ast_pct_var_diff_vs_opponent_feature         2221.466403
# 25                  team_aggregate_past_50_game_min_player_stats_aggregated_by_game_trb_skew_diff_vs_opponent_feature         2207.079988
# 23                team_aggregate_past_10_game_var_player_stats_aggregated_by_game_ts_pct_avg_diff_vs_opponent_feature         1974.380166
# 94                team_aggregate_past_1_game_avg_player_stats_aggregated_by_game_blk_pct_max_diff_vs_opponent_feature         1843.831247
# 7                 team_aggregate_past_10_game_max_player_stats_aggregated_by_game_fg_pct_avg_diff_vs_opponent_feature         1837.428143
# 96            team_aggregate_past_20_game_skew_player_stats_aggregated_by_game_ft_pct_median_diff_vs_opponent_feature         1814.843461
# 105                  team_aggregate_past_50_game_var_player_stats_aggregated_by_game_fta_max_diff_vs_opponent_feature         1613.128472
# 86   team_aggregate_past_3_game_skew_player_stats_aggregated_by_game_fg3a_per_fga_pct_median_diff_vs_opponent_feature         1589.709062
# 229                                               team_aggregate_past_20_game_avg_score_diff_diff_vs_opponent_feature         1538.796017
# 174                                    team_aggregate_past_5_game_skew_player_stats_aggregated_by_game_drb_pct_median         1455.238425
# 135                                       team_aggregate_past_3_game_skew_player_stats_aggregated_by_game_usg_pct_var         1449.471030
# 106                 team_aggregate_past_3_game_skew_player_stats_aggregated_by_game_fg3a_var_diff_vs_opponent_feature         1438.362790
# 34                   team_aggregate_past_20_game_avg_player_stats_aggregated_by_game_ft_skew_diff_vs_opponent_feature         1436.541939
# 37      team_aggregate_past_3_game_skew_player_stats_aggregated_by_game_fg3a_per_fga_pct_max_diff_vs_opponent_feature         1429.714193
# 176                                        team_aggregate_past_20_game_var_player_stats_aggregated_by_game_fg_pct_max         1410.358067
# 170                   team_aggregate_past_5_game_var_player_stats_aggregated_by_game_stl_max_diff_vs_opponent_feature         1409.202285
# 56                                                    team_aggregate_past_10_game_max_fg_pct_diff_vs_opponent_feature         1403.907691
# 192                                             team_aggregate_past_3_game_var_player_stats_aggregated_by_game_pf_var         1385.376200
# 21                                team_aggregate_past_100_game_skew_player_stats_aggregated_by_game_plus_minus_median         1368.689010
# 121          team_aggregate_past_100_game_avg_player_stats_aggregated_by_game_plus_minus_max_diff_vs_opponent_feature         1345.614906
# 42            team_aggregate_past_5_game_skew_player_stats_aggregated_by_game_ast_pct_median_diff_vs_opponent_feature         1328.270952
# 117                                           team_aggregate_past_3_game_skew_player_stats_aggregated_by_game_trb_max         1287.880339
# 41            team_aggregate_past_5_game_max_player_stats_aggregated_by_game_plus_minus_skew_diff_vs_opponent_feature         1278.593694
# 129                   team_aggregate_past_5_game_avg_player_stats_aggregated_by_game_ast_var_diff_vs_opponent_feature         1255.081608
# 187                              team_aggregate_past_3_game_var_player_stats_aggregated_by_game_fg3a_per_fga_pct_skew         1226.587240
# 149             team_aggregate_past_10_game_skew_player_stats_aggregated_by_game_ast_pct_avg_diff_vs_opponent_feature         1224.978000
# 31             team_aggregate_past_5_game_var_player_stats_aggregated_by_game_stl_pct_median_diff_vs_opponent_feature         1221.653380
# 84                                           team_aggregate_past_3_game_skew_player_stats_aggregated_by_game_orb_skew         1216.418337
# 14                    team_aggregate_past_3_game_avg_player_stats_aggregated_by_game_stl_var_diff_vs_opponent_feature         1205.035315
# 188                                       team_aggregate_past_5_game_skew_player_stats_aggregated_by_game_tov_pct_var         1200.080087
# 26                    team_aggregate_past_1_game_avg_player_stats_aggregated_by_game_orb_avg_diff_vs_opponent_feature         1177.486119
# 126                                         team_aggregate_past_3_game_skew_fg3a_per_fga_pct_diff_vs_opponent_feature         1176.578432
# 83                                                                            team_aggregate_past_3_game_skew_drb_pct         1133.817451
# 36       team_aggregate_past_5_game_min_player_stats_aggregated_by_game_fg3a_per_fga_pct_var_diff_vs_opponent_feature         1126.834077
# 60                  team_aggregate_past_20_game_avg_player_stats_aggregated_by_game_fta_skew_diff_vs_opponent_feature         1117.672350
# 30              team_aggregate_past_3_game_skew_player_stats_aggregated_by_game_trb_pct_skew_diff_vs_opponent_feature         1117.000072
# 16                   team_aggregate_past_3_game_skew_player_stats_aggregated_by_game_trb_max_diff_vs_opponent_feature         1112.794768
# 63                team_aggregate_past_3_game_var_player_stats_aggregated_by_game_def_rtg_max_diff_vs_opponent_feature         1110.911622
# 118             team_aggregate_past_50_game_max_player_stats_aggregated_by_game_stl_pct_skew_diff_vs_opponent_feature         1096.577099
# 50                                team_aggregate_past_3_game_var_player_stats_aggregated_by_game_fg3a_per_fga_pct_avg         1094.995180
# 79                                         team_aggregate_past_3_game_skew_player_stats_aggregated_by_game_ft_pct_var         1089.890550
# 182               team_aggregate_past_3_game_min_player_stats_aggregated_by_game_efg_pct_var_diff_vs_opponent_feature         1071.120859
# 57               team_aggregate_past_10_game_min_player_stats_aggregated_by_game_trb_pct_var_diff_vs_opponent_feature         1069.270622
# 5             team_aggregate_past_10_game_avg_player_stats_aggregated_by_game_plus_minus_avg_diff_vs_opponent_feature         1067.408650
# 102                  team_aggregate_past_3_game_skew_player_stats_aggregated_by_game_fg_skew_diff_vs_opponent_feature         1057.972540
# 70                                         team_aggregate_past_3_game_var_player_stats_aggregated_by_game_stl_pct_avg         1048.973399
# 28               team_aggregate_past_20_game_max_player_stats_aggregated_by_game_usg_pct_avg_diff_vs_opponent_feature         1045.023311
# 44           team_aggregate_past_10_game_skew_player_stats_aggregated_by_game_efg_pct_median_diff_vs_opponent_feature         1039.112340
# 47            team_aggregate_past_5_game_skew_player_stats_aggregated_by_game_orb_pct_median_diff_vs_opponent_feature         1038.552963
# 169             team_aggregate_past_3_game_skew_player_stats_aggregated_by_game_def_rtg_skew_diff_vs_opponent_feature         1033.797210
# 27               team_aggregate_past_3_game_max_player_stats_aggregated_by_game_def_rtg_skew_diff_vs_opponent_feature         1026.353184
# 19                                      team_aggregate_past_20_game_skew_player_stats_aggregated_by_game_blk_pct_skew         1024.973652
# 112                                           team_aggregate_past_5_game_min_player_stats_aggregated_by_game_drb_skew         1020.255458
# 22                team_aggregate_past_10_game_max_player_stats_aggregated_by_game_ts_pct_var_diff_vs_opponent_feature         1016.586090
# 128                   team_aggregate_past_3_game_avg_player_stats_aggregated_by_game_orb_avg_diff_vs_opponent_feature         1016.297477
# 156                                            team_aggregate_past_3_game_max_player_stats_aggregated_by_game_fg_skew         1015.645602
# 133                                       team_aggregate_past_10_game_max_player_stats_aggregated_by_game_ast_pct_avg         1010.465051
# 113                                       team_aggregate_past_3_game_var_player_stats_aggregated_by_game_def_rtg_skew         1009.951849
# 161                  team_aggregate_past_1_game_min_player_stats_aggregated_by_game_orb_skew_diff_vs_opponent_feature         1008.855642
# 215                                                   team_aggregate_past_1_game_avg_trb_pct_diff_vs_opponent_feature         1007.847041
# 61                  team_aggregate_past_10_game_var_player_stats_aggregated_by_game_fg3a_avg_diff_vs_opponent_feature         1004.306347
# 202                 team_aggregate_past_1_game_avg_player_stats_aggregated_by_game_fg3a_skew_diff_vs_opponent_feature         1000.225653
# 218                                           team_aggregate_past_3_game_skew_player_stats_aggregated_by_game_trb_avg          991.736840
# 212                                             team_aggregate_past_1_game_avg_player_stats_aggregated_by_game_pf_avg          986.344656
# 148                                     team_aggregate_past_20_game_skew_player_stats_aggregated_by_game_tov_pct_skew          983.146247
# 76        team_aggregate_past_100_game_avg_player_stats_aggregated_by_game_plus_minus_median_diff_vs_opponent_feature          978.449601
# 177                    team_aggregate_past_5_game_var_player_stats_aggregated_by_game_ft_max_diff_vs_opponent_feature          978.429177
# 11          team_aggregate_past_5_game_avg_player_stats_aggregated_by_game_plus_minus_median_diff_vs_opponent_feature          976.490188
# 9                team_aggregate_past_10_game_max_player_stats_aggregated_by_game_efg_pct_avg_diff_vs_opponent_feature          967.017954
# 167                                     team_aggregate_past_3_game_var_days_since_last_match_diff_vs_opponent_feature          946.380450
# 221                   team_aggregate_past_5_game_skew_player_stats_aggregated_by_game_ft_max_diff_vs_opponent_feature          945.342371
# 46                                      team_aggregate_past_3_game_var_player_stats_aggregated_by_game_usg_pct_median          940.527469
# 17                                         team_aggregate_past_3_game_var_player_stats_aggregated_by_game_orb_pct_var          935.474094
# 165                   team_aggregate_past_10_game_var_player_stats_aggregated_by_game_mp_var_diff_vs_opponent_feature          933.721738
# 227           team_aggregate_past_10_game_avg_player_stats_aggregated_by_game_plus_minus_max_diff_vs_opponent_feature          932.766551
# 207               team_aggregate_past_50_game_var_player_stats_aggregated_by_game_ft_pct_max_diff_vs_opponent_feature          931.569798
# 194             team_aggregate_past_5_game_skew_player_stats_aggregated_by_game_fg3_pct_skew_diff_vs_opponent_feature          926.932410
# 123          team_aggregate_past_10_game_skew_player_stats_aggregated_by_game_plus_minus_var_diff_vs_opponent_feature          922.184261
# 12                                         team_aggregate_past_50_game_skew_fg3a_per_fga_pct_diff_vs_opponent_feature          917.128037
# 52                                      team_aggregate_past_3_game_var_player_stats_aggregated_by_game_plus_minus_max          915.732510
# 93                  team_aggregate_past_50_game_var_player_stats_aggregated_by_game_trb_skew_diff_vs_opponent_feature          912.229189
# 172     team_aggregate_past_10_game_min_player_stats_aggregated_by_game_fta_per_fga_pct_skew_diff_vs_opponent_feature          905.399209
# 131                                    team_aggregate_past_20_game_var_player_stats_aggregated_by_game_tov_pct_median          902.801601
# 4                 team_aggregate_past_50_game_avg_player_stats_aggregated_by_game_ts_pct_var_diff_vs_opponent_feature          899.251605
# 97                                           team_aggregate_past_3_game_skew_player_stats_aggregated_by_game_fg3a_max          897.079621
# 6                     team_aggregate_past_3_game_var_player_stats_aggregated_by_game_fga_max_diff_vs_opponent_feature          890.030669
# 206                                        team_aggregate_past_5_game_min_player_stats_aggregated_by_game_tov_pct_avg          889.777901
# 190                                           team_aggregate_past_3_game_skew_player_stats_aggregated_by_game_pts_avg          887.943649
# 18               team_aggregate_past_5_game_skew_player_stats_aggregated_by_game_drb_pct_max_diff_vs_opponent_feature          883.233578
# 68                                          team_aggregate_past_3_game_max_player_stats_aggregated_by_game_ft_pct_var          879.730341
# 54                                        team_aggregate_past_10_game_skew_player_stats_aggregated_by_game_fta_median          877.702526
# 226                                                      team_aggregate_past_10_game_avg_pts_diff_vs_opponent_feature          876.690134
# 130               team_aggregate_past_20_game_max_player_stats_aggregated_by_game_ft_pct_avg_diff_vs_opponent_feature          872.638921
# 141                                          team_aggregate_past_3_game_var_player_stats_aggregated_by_game_fg3a_skew          870.005166
# 81                                            team_aggregate_past_3_game_var_player_stats_aggregated_by_game_tov_skew          864.665518

# %%
lgbm_params = {
    'boosting_type': 'gbdt',
    'objective': 'l2',
    'metric': 'mae',
    "learning_rate": 0.01,
    "max_depth": -1,
    'num_leaves': 127,
}

lgbm_params_fast = copy.deepcopy(lgbm_params)
lgbm_params_fast['learning_rate'] = .1

model = Model('lightgbm', lgbm_params)
x_train, x_test, y_train, y_test = model_selection.train_test_split(x, y2)

# %%
reg_columns = gbm_rfe(x_train, y_train, lgbm_params_fast, step_size=.01, min_features=4, score_type = 'r2_score')
x_train.shape, len(reg_columns)
# Out:
# function: 'fit' starting
# entered fit, x shape: (5465, 14436)
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/home/td/anaconda3/envs/sports_predictor/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3326, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-12-a60330100772>", line 1, in <module>
#     reg_columns = gbm_rfe(x_train, y_train, lgbm_params_fast, step_size=.01, min_features=4, score_type = 'r2_score')
#   File "<ipython-input-4-baf2edd796d5>", line 9, in gbm_rfe
#     model.fit(x_train[features], y_train)
#   File "/home/td/Documents/sports_predictor/nba/common.py", line 53, in timed
#     result = method(*args, **kw)
#   File "<ipython-input-3-9f22ee4bef3a>", line 28, in fit
#     verbose_eval=100
#   File "/home/td/anaconda3/envs/sports_predictor/lib/python3.7/site-packages/lightgbm/engine.py", line 249, in train
#     booster.update(fobj=fobj)
#   File "/home/td/anaconda3/envs/sports_predictor/lib/python3.7/site-packages/lightgbm/basic.py", line 1926, in update
#     ctypes.byref(is_finished)))
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/td/anaconda3/envs/sports_predictor/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2040, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/td/anaconda3/envs/sports_predictor/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/td/anaconda3/envs/sports_predictor/lib/python3.7/site-packages/IPython/core/ultratb.py", line 319, in wrapped
#     return f(*args, **kwargs)
#   File "/home/td/anaconda3/envs/sports_predictor/lib/python3.7/site-packages/IPython/core/ultratb.py", line 353, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/home/td/anaconda3/envs/sports_predictor/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/home/td/anaconda3/envs/sports_predictor/lib/python3.7/inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/home/td/anaconda3/envs/sports_predictor/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/home/td/anaconda3/envs/sports_predictor/lib/python3.7/inspect.py", line 742, in getmodule
#     os.path.realpath(f)] = module.__name__
#   File "/home/td/anaconda3/envs/sports_predictor/lib/python3.7/posixpath.py", line 395, in realpath
#     path, ok = _joinrealpath(filename[:0], filename, {})
#   File "/home/td/anaconda3/envs/sports_predictor/lib/python3.7/posixpath.py", line 429, in _joinrealpath
#     if not islink(newpath):
#   File "/home/td/anaconda3/envs/sports_predictor/lib/python3.7/posixpath.py", line 171, in islink
#     st = os.lstat(path)
# KeyboardInterrupt
# ---------------------------------------------------------------------------

# %%
model.fit(x_train, y_train)
preds = model.predict(x_test)
preds = np.rint(preds).astype(int)     
metrics.r2_score(y_test, preds)

# %%
model.evaluate().head(100)
